# %%
grades= [19,16,20,17.5,18]
courses = ["Math","physic","Arts","Science","Programming"]

# %%
print(courses[4], grades[4])
# Out:
# Programming 18

# %%
#dict1 = {key1: value1, ....}
course_grades= {"Math":19,"Physic":16,"Art":20,"Science":17.5,"Programming":18}

# %%
type(course_grades)
# Out:
# dict

# %%
course_grades["Math"]
# Out:
# 19

# %%
#محدودیت های تعریف دیکشنری

# %%
d2 = {'name':'shah'}
d3 = {1:'Jan', 2:'Feb', 3:'Mar'}
print(d2,d3[1])
# Out:
# {'name': 'shah'} Jan

# %%
from PIL import Image

# %%
# ouvre une image
def ouvrir():
    nomimg="lena.jpg"
  #  print(nomimg.format)
   # print(nomimg.mode)
    #print(nomimg.size)
    return Image.open(nomimg)
ouvrir()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=740x729 at 0x17E28CD6548>
